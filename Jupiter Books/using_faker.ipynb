# %% [markdown]
# ### Rationale for Utilizing the Faker Library
#
# The Faker library is being employed in the initial phases of this project primarily due to the current paucity of available data pertaining to user tasks. The development of a functional machine learning model, specifically for task duration prediction, necessitates a dataset of sufficient size and diversity. Given the limited volume of real-world task data at this juncture, synthetic data generation is essential to:
#
# * **Facilitate Early Model Development:** The generation of synthetic task descriptions and durations using Faker enables the creation of a preliminary dataset suitable for training and evaluating basic machine learning models. This allows for the iterative refinement of the model architecture and training process in the absence of real-world data.
#
# * **Enable Initial Testing:** Synthetic data provides a controlled environment for conducting initial testing of the task scheduling system and its integration with the duration prediction model. This ensures that core functionalities can be validated prior to deployment in a production environment with genuine user data.

# %%
# File Sharing
import csv

# Faker Library
from faker import Faker

# Other 
import random as random
from datetime import datetime, timedelta
from typing import List, Dict

# %%
# Initialise Faker Object
fake = Faker()

# %%
# Task Generation Params , Number of tasks will simulate a 4 month period
num_work_tasks = 4*5*4*4 # 4 Tasks per week , 5 days a week
num_study_tasks = 2*4*4 # Expected to work on coding personal coding projects twice a week
num_personal_health_and_wellbeing = 4*4*4 # Expected to go gym 4 times a week
num_of_house_tasks = 2*4*4 + 4 # Expected to change bed sheets once a month hence +4
num_of_social_tasks = 7

# %%
# List of tasks that correspond to each area and list of tags that could be used for each task in a given area
work = [
    "Attend Meeting",
    "Analyse Data",
    "4-eye Check",
    "Change BOM on SAP",
    "Test Product",
    "Calculate Savings",
    "Evaluate Data",
    "Present Data Insights",
    "Review Process"
]

work_tags = ["Data Science", "Adminstration", "Quality Engineering"]

personal_health_and_wellbeing = [
    "Gym",
    "Running",
    "Buy Cream",
    "Buy Face Wash",
    "Go GP Appointment"
]

personal_health_and_wellbeing_tags = ["Fitness", "Personal Care"]

study = [
    "Read Research Papers",
    "Coding",
    "Add Comments",
    "Watch Guide",
]

study_tags = ["Programming"]

social = [
    "Go to Resturant",
    "Go Pub",
    "Go to Cinema",
    "Go Aunty's House",
    "Go Aunty's House",
    "Go Aunty's House"
]

social_tags = ["Family", "Friends"]

home = [
    "Laundry",
    "Clean Room",
    "Change Bed Sheets"
]

home_tags = []

# %%
# initialise tasks (List of Dict)
tasks = [] 

def generate_tasks(area, num_tasks, common_tasks, dur_min, dur_max, tags=[""]):
    # Initalise Tasks
    tasks = []
    # Iterate through the number of tasks to be generated
    for num in range(num_tasks):
        task = {
            "title" : random.choice(common_tasks),
            "description" : fake.sentence(nb_words=6),
            "duration" : random.randint(dur_min, dur_max),
            "tags" : [area, random.choice(tags) ]
        }
        # Append
        tasks.append(task)
        
    # Return
    return tasks

# Extend Dict for all areas of productivity (Extend adds the elements of the list)
tasks.extend(generate_tasks("work", num_work_tasks, work, 15, 120, work_tags))
tasks.extend(generate_tasks("Health & Wellbeing", num_personal_health_and_wellbeing, personal_health_and_wellbeing, 25, 90, personal_health_and_wellbeing_tags))
tasks.extend(generate_tasks("Study", num_study_tasks, study, 20, 60, study_tags))
tasks.extend(generate_tasks("Friends&Family", num_of_social_tasks, social, 180,350, social_tags))
tasks.extend(generate_tasks("Home", num_of_house_tasks, home, 15, 40))

# %%
tasks
# Out:
# [{'title': 'Evaluate Data',
#   'description': 'Piece probably business next out my.',
#   'duration': 71,
#   'tags': ['work', 'Adminstration']},
#  {'title': '4-eye Check',
#   'description': 'Four by edge travel safe.',
#   'duration': 71,
#   'tags': ['work', 'Data Science']},
#  {'title': '4-eye Check',
#   'description': 'Market those notice red.',
#   'duration': 78,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Calculate Savings',
#   'description': 'Last history join probably feeling entire little.',
#   'duration': 62,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Evaluate Data',
#   'description': 'Wear western pressure energy paper.',
#   'duration': 94,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Analyse Data',
#   'description': 'Tell which son would hotel here bag.',
#   'duration': 61,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Analyse Data',
#   'description': 'Least value try next glass personal choice.',
#   'duration': 116,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Woman scientist person themselves hand.',
#   'duration': 71,
#   'tags': ['work', 'Adminstration']},
#  {'title': '4-eye Check',
#   'description': 'Point street record because.',
#   'duration': 27,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Present Data Insights',
#   'description': 'Anyone also environmental Mrs glass adult.',
#   'duration': 50,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Present Data Insights',
#   'description': 'Draw evening particularly song newspaper.',
#   'duration': 32,
#   'tags': ['work', 'Data Science']},
#  {'title': '4-eye Check',
#   'description': 'Result type hospital but wonder.',
#   'duration': 26,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': '4-eye Check',
#   'description': 'Argue notice name firm tree Mr much.',
#   'duration': 95,
#   'tags': ['work', 'Data Science']},
#  {'title': '4-eye Check',
#   'description': 'Young participant difficult lay close later election.',
#   'duration': 86,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': '4-eye Check',
#   'description': 'Law whatever item worry through dog.',
#   'duration': 79,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Less five close you.',
#   'duration': 120,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Review Process',
#   'description': 'On police central million.',
#   'duration': 44,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': '4-eye Check',
#   'description': 'Return appear exist.',
#   'duration': 27,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Attend Meeting',
#   'description': 'Entire person final want.',
#   'duration': 63,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Attend Meeting',
#   'description': 'Would three let.',
#   'duration': 63,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Attend Meeting',
#   'description': 'Continue case sort seek TV.',
#   'duration': 89,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Method above action science majority director them require.',
#   'duration': 90,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Change BOM on SAP',
#   'description': 'After game TV suggest again position beyond.',
#   'duration': 43,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Attend Meeting',
#   'description': 'Dark just usually arrive shake woman.',
#   'duration': 32,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Present Data Insights',
#   'description': 'One how memory nice magazine benefit professional service.',
#   'duration': 62,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Present Data Insights',
#   'description': 'Something brother whole shake late administration brother.',
#   'duration': 97,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Calculate Savings',
#   'description': 'May movement effect right.',
#   'duration': 35,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Test Product',
#   'description': 'Drive various hold federal tax.',
#   'duration': 44,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Calculate Savings',
#   'description': 'Buy letter whose.',
#   'duration': 82,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Calculate Savings',
#   'description': 'Weight expect inside executive after look.',
#   'duration': 82,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Feel child later training product forward project project.',
#   'duration': 38,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Analyse Data',
#   'description': 'Let political business poor beyond child effect sure.',
#   'duration': 68,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Something piece actually design specific consider hit.',
#   'duration': 15,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Calculate Savings',
#   'description': 'Project force lawyer ahead option enter consider.',
#   'duration': 77,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Review Process',
#   'description': 'Program the middle leg small point you.',
#   'duration': 27,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Present Data Insights',
#   'description': 'Weight guess positive public natural try value.',
#   'duration': 85,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Calculate Savings',
#   'description': 'Challenge eye age customer large charge anything.',
#   'duration': 73,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Present Data Insights',
#   'description': 'Difficult song bad sell.',
#   'duration': 93,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Review Process',
#   'description': 'Board I high candidate.',
#   'duration': 70,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': '4-eye Check',
#   'description': 'Trip difficult simply yard.',
#   'duration': 117,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Calculate Savings',
#   'description': 'Pick pick few mind end budget.',
#   'duration': 83,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Present Data Insights',
#   'description': 'Glass bank Mrs building.',
#   'duration': 56,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Else major lay often son woman everyone.',
#   'duration': 61,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Calculate Savings',
#   'description': 'Society game matter once.',
#   'duration': 43,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Present Data Insights',
#   'description': 'Executive step win world continue particularly.',
#   'duration': 31,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Change BOM on SAP',
#   'description': 'May set enter notice tax special.',
#   'duration': 21,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Analyse Data',
#   'description': 'Item personal first seat generation the.',
#   'duration': 118,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Attend Meeting',
#   'description': 'Other wife clear.',
#   'duration': 26,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Attend Meeting',
#   'description': 'Front face Mrs exactly senior cold them ability.',
#   'duration': 57,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Test Product',
#   'description': 'Look policy take would guess peace.',
#   'duration': 73,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Attend Meeting',
#   'description': 'Federal though executive despite son ground back teach.',
#   'duration': 70,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Present Data Insights',
#   'description': 'More whose focus pay positive especially share.',
#   'duration': 119,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Review Process',
#   'description': 'Former reflect later themselves hit action.',
#   'duration': 99,
#   'tags': ['work', 'Adminstration']},
#  {'title': '4-eye Check',
#   'description': 'Doctor which at production.',
#   'duration': 73,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Test Product',
#   'description': 'Less someone clear behind however yes step.',
#   'duration': 44,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Calculate Savings',
#   'description': 'Stuff medical research walk health.',
#   'duration': 35,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Review Process',
#   'description': 'Option election follow perform late ten ahead.',
#   'duration': 57,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Test Product',
#   'description': 'Oil realize structure PM skill near.',
#   'duration': 79,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Present Data Insights',
#   'description': 'Consumer account human will as center.',
#   'duration': 36,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Material loss mission operation.',
#   'duration': 58,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Evaluate Data',
#   'description': 'None imagine peace accept point community each.',
#   'duration': 79,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Analyse Data',
#   'description': 'Street direction television.',
#   'duration': 87,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Calculate Savings',
#   'description': 'Community born forward eat prevent.',
#   'duration': 47,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Evaluate Data',
#   'description': 'Sing beautiful assume place evening.',
#   'duration': 43,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Evaluate Data',
#   'description': 'Agency live type our summer could force.',
#   'duration': 23,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Team court change mention know yes responsibility.',
#   'duration': 56,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Analyse Data',
#   'description': 'Them worry ground fall side challenge.',
#   'duration': 112,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Test Product',
#   'description': 'Interest feeling myself suffer election.',
#   'duration': 111,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Analyse Data',
#   'description': 'Music write buy pattern guy hit support collection.',
#   'duration': 102,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Evaluate Data',
#   'description': 'Prevent different heavy outside describe.',
#   'duration': 34,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Analyse Data',
#   'description': 'Good also key.',
#   'duration': 49,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Present Data Insights',
#   'description': 'Information suggest soldier report either word.',
#   'duration': 46,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Production indicate month report position forward television drug.',
#   'duration': 111,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Evaluate Data',
#   'description': 'Feel none common about.',
#   'duration': 16,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Review Process',
#   'description': 'College later themselves especially Republican source black.',
#   'duration': 44,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Evaluate Data',
#   'description': 'To want social east Congress research.',
#   'duration': 69,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Bag field far leave.',
#   'duration': 102,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': '4-eye Check',
#   'description': 'Catch these I hard amount artist history.',
#   'duration': 67,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Evaluate Data',
#   'description': 'Cover simple item management spring onto.',
#   'duration': 82,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Attend Meeting',
#   'description': 'Arm job animal firm present father through around.',
#   'duration': 50,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Current show dog moment physical Mrs.',
#   'duration': 22,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Calculate Savings',
#   'description': 'Former control section scientist man product citizen.',
#   'duration': 115,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Analyse Data',
#   'description': 'Idea green radio.',
#   'duration': 39,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Attend Meeting',
#   'description': 'What politics discussion color south rest feeling.',
#   'duration': 26,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Test Product',
#   'description': 'Card size score happen condition.',
#   'duration': 77,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Calculate Savings',
#   'description': 'Who want sound entire.',
#   'duration': 57,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Test Product',
#   'description': 'Act standard power tough new cell.',
#   'duration': 104,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Present Data Insights',
#   'description': 'Save wall fight community yeah head big.',
#   'duration': 58,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Attend Meeting',
#   'description': 'Maybe phone sure well community budget social employee.',
#   'duration': 113,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Analyse Data',
#   'description': 'Bag suddenly body bank.',
#   'duration': 74,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Eight thousand the model laugh.',
#   'duration': 19,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Review Process',
#   'description': 'Start develop price choice use lawyer catch.',
#   'duration': 104,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Review Process',
#   'description': 'That dog computer seem add audience.',
#   'duration': 101,
#   'tags': ['work', 'Adminstration']},
#  {'title': '4-eye Check',
#   'description': 'Item spend leg third back.',
#   'duration': 43,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Analyse Data',
#   'description': 'After activity describe question.',
#   'duration': 100,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Calculate Savings',
#   'description': 'Threat morning morning water old.',
#   'duration': 40,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Attend Meeting',
#   'description': 'She forward order true sure.',
#   'duration': 33,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': '4-eye Check',
#   'description': 'That develop will chance blood risk speech avoid.',
#   'duration': 100,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Evaluate Data',
#   'description': 'Majority indeed guy art.',
#   'duration': 105,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Calculate Savings',
#   'description': 'Democratic pass important spring along us.',
#   'duration': 66,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Evaluate Data',
#   'description': 'Let environmental western piece join.',
#   'duration': 94,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Test Product',
#   'description': 'Decide respond cost character sport low.',
#   'duration': 88,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Gas best pull responsibility thousand clearly.',
#   'duration': 18,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Review Process',
#   'description': 'Strategy week stand.',
#   'duration': 61,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Review Process',
#   'description': 'Perform movement animal society you.',
#   'duration': 30,
#   'tags': ['work', 'Adminstration']},
#  {'title': '4-eye Check',
#   'description': 'Task treatment receive marriage.',
#   'duration': 97,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Evaluate Data',
#   'description': 'Whole recent produce mouth form.',
#   'duration': 90,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Analyse Data',
#   'description': 'Job director according police very film board.',
#   'duration': 72,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Review Process',
#   'description': 'Support answer trouble including.',
#   'duration': 83,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Still more he such citizen house.',
#   'duration': 74,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Evaluate Data',
#   'description': 'Child create religious approach factor.',
#   'duration': 107,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Present Data Insights',
#   'description': 'Property short artist themselves.',
#   'duration': 32,
#   'tags': ['work', 'Adminstration']},
#  {'title': '4-eye Check',
#   'description': 'Mouth fact enter mention ago fish sister.',
#   'duration': 42,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Attend Meeting',
#   'description': 'Rather police go candidate water two Democrat professional.',
#   'duration': 108,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Present Data Insights',
#   'description': 'Either side there.',
#   'duration': 78,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Attend Meeting',
#   'description': 'Tell off religious writer hit candidate seem.',
#   'duration': 95,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Present Data Insights',
#   'description': 'Trip order able including guess.',
#   'duration': 72,
#   'tags': ['work', 'Data Science']},
#  {'title': '4-eye Check',
#   'description': 'Physical rate member market.',
#   'duration': 20,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Calculate Savings',
#   'description': 'None tell thus stock bring first.',
#   'duration': 25,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Us difference budget stage me.',
#   'duration': 106,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Analyse Data',
#   'description': 'Eight they simple form important investment.',
#   'duration': 21,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Attend Meeting',
#   'description': 'Authority weight character in.',
#   'duration': 38,
#   'tags': ['work', 'Adminstration']},
#  {'title': '4-eye Check',
#   'description': 'Hear method information politics explain.',
#   'duration': 46,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Present Data Insights',
#   'description': 'Drug rule low large girl again.',
#   'duration': 36,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Calculate Savings',
#   'description': 'Nice fire size indicate large.',
#   'duration': 56,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Analyse Data',
#   'description': 'Church agency room if the.',
#   'duration': 51,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Review Process',
#   'description': 'Poor population feeling themselves change member.',
#   'duration': 29,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Evaluate Data',
#   'description': 'Want lawyer strategy who.',
#   'duration': 18,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Around future turn thought.',
#   'duration': 70,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Review Process',
#   'description': 'Opportunity gun population water imagine.',
#   'duration': 36,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Present Data Insights',
#   'description': 'Through traditional raise threat language treatment response.',
#   'duration': 99,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Attend Meeting',
#   'description': 'Product six serve traditional.',
#   'duration': 67,
#   'tags': ['work', 'Data Science']},
#  {'title': '4-eye Check',
#   'description': 'Impact city administration eat.',
#   'duration': 16,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Focus wish others political trade dog.',
#   'duration': 57,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Calculate Savings',
#   'description': 'Pressure agency nearly break.',
#   'duration': 77,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Calculate Savings',
#   'description': 'Second themselves spring painting also heavy culture interesting.',
#   'duration': 77,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Mean when need military teach risk.',
#   'duration': 92,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Review Process',
#   'description': 'Treatment indicate region cold.',
#   'duration': 112,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Attend Meeting',
#   'description': 'Travel ahead it long interview.',
#   'duration': 78,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Review Process',
#   'description': 'Group set situation dream race lot toward.',
#   'duration': 95,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Attend Meeting',
#   'description': 'Simply allow last audience.',
#   'duration': 52,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Calculate Savings',
#   'description': 'Cold wide standard.',
#   'duration': 80,
#   'tags': ['work', 'Data Science']},
#  {'title': '4-eye Check',
#   'description': 'Late life often degree region best until.',
#   'duration': 86,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Out person fund result wife top seat stuff.',
#   'duration': 107,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Analyse Data',
#   'description': 'Phone present doctor quickly.',
#   'duration': 40,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Attend Meeting',
#   'description': 'Least season husband actually phone push bad.',
#   'duration': 48,
#   'tags': ['work', 'Adminstration']},
#  {'title': '4-eye Check',
#   'description': 'State early unit sign perform population seat.',
#   'duration': 102,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Attend Meeting',
#   'description': 'Yourself huge fire beautiful knowledge draw.',
#   'duration': 22,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Evaluate Data',
#   'description': 'Others often seek attorney.',
#   'duration': 112,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Attend Meeting',
#   'description': 'Strategy remain purpose push laugh event.',
#   'duration': 41,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Evaluate Data',
#   'description': 'Risk hear break product.',
#   'duration': 64,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Analyse Data',
#   'description': 'Ground federal issue ever late become street.',
#   'duration': 37,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Attend Meeting',
#   'description': 'Power series color.',
#   'duration': 48,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Attend Meeting',
#   'description': 'Cover newspaper open and recent allow threat.',
#   'duration': 90,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Rise something product find partner now opportunity star.',
#   'duration': 68,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Evaluate Data',
#   'description': 'Main institution he sort political.',
#   'duration': 111,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Present Data Insights',
#   'description': 'Third some large.',
#   'duration': 15,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Review Process',
#   'description': 'Action the before smile southern three.',
#   'duration': 54,
#   'tags': ['work', 'Adminstration']},
#  {'title': '4-eye Check',
#   'description': 'Action community religious series grow care everyone.',
#   'duration': 78,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Calculate Savings',
#   'description': 'Military ok sit do.',
#   'duration': 28,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Review Process',
#   'description': 'Which environment difficult purpose form.',
#   'duration': 116,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Present Data Insights',
#   'description': 'South house item public.',
#   'duration': 106,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Present Data Insights',
#   'description': 'Arm here finally ahead quality page system.',
#   'duration': 28,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Test Product',
#   'description': 'Reason law property natural high it truth.',
#   'duration': 41,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Test Product',
#   'description': 'Senior loss relationship yard people firm actually.',
#   'duration': 39,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Evaluate Data',
#   'description': 'Bag no whatever page process.',
#   'duration': 37,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Field place for treat him small test.',
#   'duration': 104,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Seem body toward possible gas.',
#   'duration': 97,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Analyse Data',
#   'description': 'Look adult risk.',
#   'duration': 47,
#   'tags': ['work', 'Adminstration']},
#  {'title': '4-eye Check',
#   'description': 'Above record reach key market apply act.',
#   'duration': 60,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Attend Meeting',
#   'description': 'Hear throughout current stage phone bit place.',
#   'duration': 55,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Change BOM on SAP',
#   'description': 'This feeling hair hour citizen join range.',
#   'duration': 111,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Present Data Insights',
#   'description': 'Above full goal generation purpose.',
#   'duration': 64,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Evaluate Data',
#   'description': 'Notice wait outside significant.',
#   'duration': 120,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Test Product',
#   'description': 'Really understand base person recent agency.',
#   'duration': 44,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Test Product',
#   'description': 'Dinner character soon itself part else another.',
#   'duration': 115,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Under away school economic wife.',
#   'duration': 78,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Compare speech again and goal.',
#   'duration': 105,
#   'tags': ['work', 'Data Science']},
#  {'title': '4-eye Check',
#   'description': 'While west form political worry way.',
#   'duration': 39,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Top family but nature positive.',
#   'duration': 15,
#   'tags': ['work', 'Adminstration']},
#  {'title': '4-eye Check',
#   'description': 'Play still sure medical prove figure hard.',
#   'duration': 54,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Calculate Savings',
#   'description': 'Fill partner power our involve more point father.',
#   'duration': 119,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Review Process',
#   'description': 'On put finish seek modern say forward.',
#   'duration': 21,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Evaluate Data',
#   'description': 'Century analysis six whole news far.',
#   'duration': 76,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Attend Meeting',
#   'description': 'Approach nice local allow skill.',
#   'duration': 67,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Present Data Insights',
#   'description': 'But work hold condition.',
#   'duration': 92,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Calculate Savings',
#   'description': 'Its bill fast fish.',
#   'duration': 43,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Attend Meeting',
#   'description': 'North would bring skin position customer.',
#   'duration': 99,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Attend Meeting',
#   'description': 'Despite apply move stage lay act clear.',
#   'duration': 40,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Review Process',
#   'description': 'Visit ago well social.',
#   'duration': 104,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Analyse Data',
#   'description': 'Bank country better three reduce.',
#   'duration': 92,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Review Process',
#   'description': 'Leave garden beautiful current.',
#   'duration': 108,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Review Process',
#   'description': 'Performance among right instead bag good item wait.',
#   'duration': 34,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Review Process',
#   'description': 'Father yourself her way step public.',
#   'duration': 75,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Test Product',
#   'description': 'Usually blue music idea.',
#   'duration': 28,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': '4-eye Check',
#   'description': 'Phone bar probably very term.',
#   'duration': 38,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Test Product',
#   'description': 'Single include reduce marriage.',
#   'duration': 118,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Review Process',
#   'description': 'Themselves live around while amount indeed but.',
#   'duration': 73,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Part traditional yes church care detail book.',
#   'duration': 110,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Evaluate Data',
#   'description': 'View establish rich important voice both.',
#   'duration': 49,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Attend Meeting',
#   'description': 'Most control project successful your cup development rise.',
#   'duration': 117,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Reflect claim participant now.',
#   'duration': 116,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': '4-eye Check',
#   'description': 'Fact close find.',
#   'duration': 62,
#   'tags': ['work', 'Data Science']},
#  {'title': '4-eye Check',
#   'description': 'Have guy white painting music on article.',
#   'duration': 99,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Analyse Data',
#   'description': 'Tell imagine eight raise difference establish.',
#   'duration': 112,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Attend Meeting',
#   'description': 'Century seem raise my debate.',
#   'duration': 35,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Attend Meeting',
#   'description': 'Middle indicate me president catch similar hotel.',
#   'duration': 76,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Hospital finish enjoy western possible.',
#   'duration': 25,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Huge news possible book.',
#   'duration': 102,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Present Data Insights',
#   'description': 'Stop wait goal church hundred.',
#   'duration': 45,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Analyse Data',
#   'description': 'Discover few wide key see page political.',
#   'duration': 113,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Present Data Insights',
#   'description': 'Employee argue close matter front notice commercial.',
#   'duration': 75,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Test Product',
#   'description': 'Past model along doctor both nation maintain produce.',
#   'duration': 103,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Review Process',
#   'description': 'Rather large include test officer return instead action.',
#   'duration': 71,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Analyse Data',
#   'description': 'Meet give painting wait little represent war.',
#   'duration': 48,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Test Product',
#   'description': 'Interesting shake defense want of life.',
#   'duration': 59,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Calculate Savings',
#   'description': 'Wife specific become yeah war somebody money.',
#   'duration': 111,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Review Process',
#   'description': 'Raise store interest already understand every rise.',
#   'duration': 31,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Test Product',
#   'description': 'Heavy bring subject begin of itself.',
#   'duration': 72,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Evaluate Data',
#   'description': 'About voice course.',
#   'duration': 61,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Analyse Data',
#   'description': 'Evening exist measure official you position simply.',
#   'duration': 68,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Attend Meeting',
#   'description': 'Member learn better through only nearly.',
#   'duration': 25,
#   'tags': ['work', 'Data Science']},
#  {'title': '4-eye Check',
#   'description': 'Cause whether whom after again.',
#   'duration': 61,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Cause debate piece manage.',
#   'duration': 81,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Evaluate Data',
#   'description': 'Activity personal talk central push current per.',
#   'duration': 27,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Evaluate Data',
#   'description': 'Summer wrong discover answer down industry sense drive.',
#   'duration': 39,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Review Process',
#   'description': 'Road without if TV second commercial.',
#   'duration': 90,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Analyse Data',
#   'description': 'Season before past ability hundred fast network.',
#   'duration': 21,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Present Data Insights',
#   'description': 'Read player maybe consumer politics agency know.',
#   'duration': 29,
#   'tags': ['work', 'Adminstration']},
#  {'title': '4-eye Check',
#   'description': 'Open all realize population.',
#   'duration': 26,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Test Product',
#   'description': 'Investment knowledge wonder soldier.',
#   'duration': 25,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Evaluate Data',
#   'description': 'Ten hotel training medical role society.',
#   'duration': 58,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Present Data Insights',
#   'description': 'Outside last figure executive case I growth.',
#   'duration': 119,
#   'tags': ['work', 'Data Science']},
#  {'title': '4-eye Check',
#   'description': 'Maybe go memory financial piece green.',
#   'duration': 101,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Suddenly election experience sometimes serve president eat which.',
#   'duration': 102,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Analyse Data',
#   'description': 'Week gun partner feeling commercial woman.',
#   'duration': 120,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Calculate Savings',
#   'description': 'Imagine open family quickly.',
#   'duration': 33,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Human machine art left wonder call effort.',
#   'duration': 25,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Review Process',
#   'description': 'Rate model more great.',
#   'duration': 91,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Analyse Data',
#   'description': 'Peace technology Democrat look.',
#   'duration': 120,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Test Product',
#   'description': 'Total front hard evidence season hotel.',
#   'duration': 30,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Attend Meeting',
#   'description': 'Receive at type.',
#   'duration': 47,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Present Data Insights',
#   'description': 'Any event condition pattern.',
#   'duration': 107,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Review Process',
#   'description': 'Behavior represent concern bill.',
#   'duration': 27,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Calculate Savings',
#   'description': 'Upon she nation kid space big blue.',
#   'duration': 21,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Analyse Data',
#   'description': 'Practice boy often difference.',
#   'duration': 55,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Line out develop expect.',
#   'duration': 54,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Unit east option statement now.',
#   'duration': 77,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Evaluate Data',
#   'description': 'To sing prepare.',
#   'duration': 83,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Analyse Data',
#   'description': 'Generation hair include.',
#   'duration': 116,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Test Product',
#   'description': 'Response adult herself key.',
#   'duration': 89,
#   'tags': ['work', 'Adminstration']},
#  {'title': '4-eye Check',
#   'description': 'Capital character speech him coach somebody.',
#   'duration': 31,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Attack thus sea song series.',
#   'duration': 18,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Evaluate Data',
#   'description': 'Throughout interest address.',
#   'duration': 51,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Analyse Data',
#   'description': 'Training different show vote statement international politics.',
#   'duration': 29,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Test Product',
#   'description': 'Stock perform ready.',
#   'duration': 20,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Review Process',
#   'description': 'Sure prepare although floor generation suffer.',
#   'duration': 102,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Test Product',
#   'description': 'Perhaps range early smile stay.',
#   'duration': 74,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Test have person very cut every.',
#   'duration': 76,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Present Data Insights',
#   'description': 'Measure improve follow real.',
#   'duration': 81,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Review Process',
#   'description': 'Bag way energy employee.',
#   'duration': 111,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Evaluate Data',
#   'description': 'Fire floor high smile.',
#   'duration': 95,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Like compare voice cover those character close.',
#   'duration': 59,
#   'tags': ['work', 'Adminstration']},
#  {'title': '4-eye Check',
#   'description': 'Action role their federal far candidate look.',
#   'duration': 114,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Test Product',
#   'description': 'Rate month whole remain culture concern.',
#   'duration': 20,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Evaluate Data',
#   'description': 'Down employee toward certain wish toward which.',
#   'duration': 32,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Calculate Savings',
#   'description': 'Leg why job today focus care.',
#   'duration': 102,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Calculate Savings',
#   'description': 'Old modern manager shoulder door particular.',
#   'duration': 77,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Evaluate Data',
#   'description': 'Police successful tell.',
#   'duration': 42,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Review Process',
#   'description': 'South service dream.',
#   'duration': 33,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Evaluate Data',
#   'description': 'Avoid by race mind near lot so.',
#   'duration': 52,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Attend Meeting',
#   'description': 'Security scientist news alone ask interview someone.',
#   'duration': 81,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Attend Meeting',
#   'description': 'Manager successful stock enough today player admit.',
#   'duration': 93,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Career standard way product.',
#   'duration': 23,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Analyse Data',
#   'description': 'Child TV card deal.',
#   'duration': 53,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Present Data Insights',
#   'description': 'Executive store role practice security notice son.',
#   'duration': 68,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Review Process',
#   'description': 'Clear sport range produce after picture.',
#   'duration': 92,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Evaluate Data',
#   'description': 'Statement sign prevent between economy current study.',
#   'duration': 112,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Test Product',
#   'description': 'However see film resource which.',
#   'duration': 26,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Test Product',
#   'description': 'Government describe family nothing house maintain fight.',
#   'duration': 95,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Test Product',
#   'description': 'Continue of drop outside.',
#   'duration': 76,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Present Data Insights',
#   'description': 'Instead event which south.',
#   'duration': 88,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Attend Meeting',
#   'description': 'Have everything check pressure television marriage.',
#   'duration': 29,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Calculate Savings',
#   'description': 'Morning affect recent special data practice.',
#   'duration': 37,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Attend Meeting',
#   'description': 'Listen field to attorney half already focus.',
#   'duration': 83,
#   'tags': ['work', 'Adminstration']},
#  {'title': '4-eye Check',
#   'description': 'Position common provide guess.',
#   'duration': 41,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Review Process',
#   'description': 'Special attack tough outside.',
#   'duration': 19,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Analyse Data',
#   'description': 'Central process people toward anything into.',
#   'duration': 110,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': '4-eye Check',
#   'description': 'Administration word scene protect little not.',
#   'duration': 82,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Review Process',
#   'description': 'Hour care wife street among nation.',
#   'duration': 115,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Test Product',
#   'description': 'Race friend ground individual owner paper.',
#   'duration': 106,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Take sister include market.',
#   'duration': 96,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Analyse Data',
#   'description': 'Material site tend enter protect.',
#   'duration': 59,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Calculate Savings',
#   'description': 'Nearly I paper benefit population class.',
#   'duration': 92,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Yes job economic present imagine.',
#   'duration': 38,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Strong cold pressure level dinner how.',
#   'duration': 71,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': '4-eye Check',
#   'description': 'Purpose whose step white thing affect choice ever.',
#   'duration': 87,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Test Product',
#   'description': 'Week from young resource.',
#   'duration': 114,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Attend Meeting',
#   'description': 'Find computer accept music law between walk.',
#   'duration': 27,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Analyse Data',
#   'description': 'Difficult to admit finally.',
#   'duration': 52,
#   'tags': ['work', 'Data Science']},
#  {'title': '4-eye Check',
#   'description': 'Kitchen finish through war suggest save life.',
#   'duration': 62,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Green as determine near any middle according.',
#   'duration': 84,
#   'tags': ['work', 'Data Science']},
#  {'title': '4-eye Check',
#   'description': 'Evening probably life second put significant argue.',
#   'duration': 95,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Soldier art later rather peace attention day.',
#   'duration': 105,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Any future send listen.',
#   'duration': 29,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Test Product',
#   'description': 'Him century direction interesting.',
#   'duration': 50,
#   'tags': ['work', 'Data Science']},
#  {'title': '4-eye Check',
#   'description': 'Trouble store a song.',
#   'duration': 60,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Present Data Insights',
#   'description': 'Commercial soldier nation apply special green easy.',
#   'duration': 47,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Attend Meeting',
#   'description': 'Improve home federal.',
#   'duration': 15,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Test Product',
#   'description': 'Worry model democratic strong Congress option order.',
#   'duration': 118,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Test Product',
#   'description': 'Turn perform meeting budget always.',
#   'duration': 55,
#   'tags': ['work', 'Adminstration']},
#  {'title': '4-eye Check',
#   'description': 'Hand item west water economic offer.',
#   'duration': 55,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Change BOM on SAP',
#   'description': 'Four according region movie training.',
#   'duration': 20,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Analyse Data',
#   'description': 'Writer place visit cold good economic especially music.',
#   'duration': 81,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Attend Meeting',
#   'description': 'Economic federal opportunity.',
#   'duration': 38,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Review Process',
#   'description': 'Mean find its consider leave lose especially month.',
#   'duration': 82,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Calculate Savings',
#   'description': 'Off detail theory important.',
#   'duration': 98,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Attend Meeting',
#   'description': 'Your movement west head deal week.',
#   'duration': 60,
#   'tags': ['work', 'Quality Engineering']},
#  {'title': 'Present Data Insights',
#   'description': 'Conference spring player military.',
#   'duration': 68,
#   'tags': ['work', 'Adminstration']},
#  {'title': 'Attend Meeting',
#   'description': 'Sometimes so his old east consider where.',
#   'duration': 86,
#   'tags': ['work', 'Data Science']},
#  {'title': 'Buy Face Wash',
#   'description': 'Change black culture feel list money instead.',
#   'duration': 26,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Buy Face Wash',
#   'description': 'Continue accept likely vote now rule.',
#   'duration': 51,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Buy Cream',
#   'description': 'Imagine commercial save owner traditional.',
#   'duration': 72,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Buy Cream',
#   'description': 'Blood born even age.',
#   'duration': 31,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Buy Cream',
#   'description': 'Tough while class bring occur dog.',
#   'duration': 49,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Go GP Appointment',
#   'description': 'Congress success fear similar.',
#   'duration': 88,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Buy Face Wash',
#   'description': 'Cut structure raise physical night according feeling.',
#   'duration': 42,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Running',
#   'description': 'Foreign notice respond me.',
#   'duration': 42,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Running',
#   'description': 'Use maintain give woman organization.',
#   'duration': 47,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Buy Cream',
#   'description': 'Its professor firm mouth listen the.',
#   'duration': 56,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Running',
# ...
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Go GP Appointment',
#   'description': 'Sound social operation north election various significant stand.',
#   'duration': 87,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Gym',
#   'description': 'Season radio rather town painting statement often different.',
#   'duration': 85,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Gym',
#   'description': 'Or cell throw risk article wear.',
#   'duration': 39,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Running',
#   'description': 'So staff knowledge.',
#   'duration': 49,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Running',
#   'description': 'Or Congress age mean kind number firm year.',
#   'duration': 28,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Buy Cream',
#   'description': 'Ball strategy drop five matter game push spring.',
#   'duration': 72,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Go GP Appointment',
#   'description': 'Cut federal low responsibility together town such.',
#   'duration': 68,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Buy Face Wash',
#   'description': 'Research whatever available total event another.',
#   'duration': 71,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Go GP Appointment',
#   'description': 'Clear affect already population.',
#   'duration': 57,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Go GP Appointment',
#   'description': 'Every democratic enter source.',
#   'duration': 81,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Buy Cream',
#   'description': 'Nor weight major.',
#   'duration': 29,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Gym',
#   'description': 'My tough each either party stock.',
#   'duration': 26,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Go GP Appointment',
#   'description': 'Language network heart for many different.',
#   'duration': 52,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Buy Cream',
#   'description': 'Tell control dinner score stay member.',
#   'duration': 43,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Buy Face Wash',
#   'description': 'Fine lead about work long.',
#   'duration': 31,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Buy Face Wash',
#   'description': 'Appear perhaps someone send well.',
#   'duration': 87,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Buy Face Wash',
#   'description': 'Decade above begin new.',
#   'duration': 63,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Running',
#   'description': 'Law system relate.',
#   'duration': 86,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Gym',
#   'description': 'Suffer bar field seem season.',
#   'duration': 80,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Buy Cream',
#   'description': 'Full feeling news.',
#   'duration': 84,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Go GP Appointment',
#   'description': 'Bag peace provide peace man impact.',
#   'duration': 46,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Gym',
#   'description': 'Me significant material left.',
#   'duration': 63,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Go GP Appointment',
#   'description': 'Car city fire section final.',
#   'duration': 86,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Buy Cream',
#   'description': 'Real read environment author item see recently exactly.',
#   'duration': 33,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Running',
#   'description': 'Policy best hear until glass type civil.',
#   'duration': 37,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Buy Cream',
#   'description': 'Than effort tree rather outside group house through.',
#   'duration': 30,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Gym',
#   'description': 'Power science military water move.',
#   'duration': 40,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Go GP Appointment',
#   'description': 'Doctor with case heavy respond thing.',
#   'duration': 53,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Buy Cream',
#   'description': 'Movie speak statement administration doctor represent today.',
#   'duration': 30,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Go GP Appointment',
#   'description': 'Direction every miss trade between rate.',
#   'duration': 42,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Running',
#   'description': 'Kind blue middle also.',
#   'duration': 82,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Buy Face Wash',
#   'description': 'I special wind employee according old occur.',
#   'duration': 90,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Buy Face Wash',
#   'description': 'Evidence fall year real.',
#   'duration': 78,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Buy Face Wash',
#   'description': 'Final professor mission.',
#   'duration': 62,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Running',
#   'description': 'Door indicate edge per guy.',
#   'duration': 38,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Gym',
#   'description': 'Site effort statement everything.',
#   'duration': 42,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Go GP Appointment',
#   'description': 'Life individual former admit ago.',
#   'duration': 39,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Running',
#   'description': 'Senior world always.',
#   'duration': 55,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Gym',
#   'description': 'Parent great last discover.',
#   'duration': 52,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Buy Face Wash',
#   'description': 'Performance heavy suffer nature.',
#   'duration': 61,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Running',
#   'description': 'Language especially social drug appear account.',
#   'duration': 43,
#   'tags': ['Health & Wellbeing', 'Personal Care']},
#  {'title': 'Buy Face Wash',
#   'description': 'Size nice method maybe.',
#   'duration': 58,
#   'tags': ['Health & Wellbeing', 'Fitness']},
#  {'title': 'Watch Guide',
#   'description': 'Keep nearly his third machine think worry.',
#   'duration': 59,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Coding',
#   'description': 'Image nice bed manage itself.',
#   'duration': 25,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Read Research Papers',
#   'description': 'Poor oil follow scene.',
#   'duration': 33,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Add Comments',
#   'description': 'Writer apply agree soon.',
#   'duration': 44,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Add Comments',
#   'description': 'Last off under note.',
#   'duration': 57,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Read Research Papers',
#   'description': 'Example mean structure debate mission.',
#   'duration': 37,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Add Comments',
#   'description': 'Character fill response tree guy learn.',
#   'duration': 48,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Watch Guide',
#   'description': 'Hold movie dinner.',
#   'duration': 34,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Add Comments',
#   'description': 'Walk war investment morning lose hope.',
#   'duration': 36,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Add Comments',
#   'description': 'Something late customer food.',
#   'duration': 39,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Read Research Papers',
#   'description': 'Just woman chair center.',
#   'duration': 46,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Read Research Papers',
#   'description': 'Tree those positive.',
#   'duration': 24,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Add Comments',
#   'description': 'Clearly win officer our.',
#   'duration': 30,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Read Research Papers',
#   'description': 'East small several result question.',
#   'duration': 45,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Watch Guide',
#   'description': 'Wind protect answer whole north enter forward.',
#   'duration': 43,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Watch Guide',
#   'description': 'Whole consider clearly important.',
#   'duration': 31,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Read Research Papers',
#   'description': 'Impact explain but quickly guy offer.',
#   'duration': 42,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Coding',
#   'description': 'Ask American nation crime.',
#   'duration': 60,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Watch Guide',
#   'description': 'Deal method nearly turn know seem authority.',
#   'duration': 39,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Add Comments',
#   'description': 'Base Congress attack only capital.',
#   'duration': 45,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Coding',
#   'description': 'Citizen now drug show reduce his onto.',
#   'duration': 55,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Add Comments',
#   'description': 'Continue view song others spring.',
#   'duration': 28,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Read Research Papers',
#   'description': 'Contain seem show spring media offer.',
#   'duration': 33,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Watch Guide',
#   'description': 'This long fund gun wear.',
#   'duration': 25,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Add Comments',
#   'description': 'Speech establish some friend foreign black.',
#   'duration': 55,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Add Comments',
#   'description': 'Daughter without page action call.',
#   'duration': 42,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Add Comments',
#   'description': 'Road campaign cell.',
#   'duration': 60,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Coding',
#   'description': 'Station fine likely night little.',
#   'duration': 45,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Coding',
#   'description': 'Daughter serve business budget to similar consider account.',
#   'duration': 51,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Add Comments',
#   'description': 'Buy light bring high imagine study popular.',
#   'duration': 27,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Coding',
#   'description': 'More deep perform management case responsibility.',
#   'duration': 55,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Watch Guide',
#   'description': 'Enough everybody guess guy.',
#   'duration': 26,
#   'tags': ['Study', 'Programming']},
#  {'title': 'Go to Resturant',
#   'description': 'Side enjoy up and detail.',
#   'duration': 222,
#   'tags': ['Friends&Family', 'Family']},
#  {'title': 'Go Pub',
#   'description': 'Foot couple whether discover require.',
#   'duration': 228,
#   'tags': ['Friends&Family', 'Friends']},
#  {'title': "Go Aunty's House",
#   'description': 'Professor front prepare while himself.',
#   'duration': 186,
#   'tags': ['Friends&Family', 'Friends']},
#  {'title': "Go Aunty's House",
#   'description': 'Model business year this.',
#   'duration': 193,
#   'tags': ['Friends&Family', 'Family']},
#  {'title': "Go Aunty's House",
#   'description': 'Game for fly weight establish leader.',
#   'duration': 295,
#   'tags': ['Friends&Family', 'Family']},
#  {'title': 'Go to Resturant',
#   'description': 'Environmental free student give.',
#   'duration': 295,
#   'tags': ['Friends&Family', 'Family']},
#  {'title': "Go Aunty's House",
#   'description': 'Few order part.',
#   'duration': 216,
#   'tags': ['Friends&Family', 'Family']},
#  {'title': 'Laundry',
#   'description': 'Authority trade of save boy season material.',
#   'duration': 34,
#   'tags': ['Home', '']},
#  {'title': 'Clean Room',
#   'description': 'Vote control everyone.',
#   'duration': 39,
#   'tags': ['Home', '']},
#  {'title': 'Change Bed Sheets',
#   'description': 'My there because.',
#   'duration': 22,
#   'tags': ['Home', '']},
#  {'title': 'Laundry',
#   'description': 'Around prove central new beat bank.',
#   'duration': 16,
#   'tags': ['Home', '']},
#  {'title': 'Clean Room',
#   'description': 'Perform heavy car.',
#   'duration': 39,
#   'tags': ['Home', '']},
#  {'title': 'Laundry',
#   'description': 'Today whose pull about suffer team.',
#   'duration': 39,
#   'tags': ['Home', '']},
#  {'title': 'Change Bed Sheets',
#   'description': 'Mother economic fall great management million.',
#   'duration': 35,
#   'tags': ['Home', '']},
#  {'title': 'Laundry',
#   'description': 'Stock possible upon us try sure.',
#   'duration': 34,
#   'tags': ['Home', '']},
#  {'title': 'Change Bed Sheets',
#   'description': 'Lawyer drop other society.',
#   'duration': 19,
#   'tags': ['Home', '']},
#  {'title': 'Change Bed Sheets',
#   'description': 'Range model land.',
#   'duration': 34,
#   'tags': ['Home', '']},
#  {'title': 'Clean Room',
#   'description': 'Ago player already success program peace quickly see.',
#   'duration': 38,
#   'tags': ['Home', '']},
#  {'title': 'Clean Room',
#   'description': 'Rather growth area back hold free room.',
#   'duration': 15,
#   'tags': ['Home', '']},
#  {'title': 'Clean Room',
#   'description': 'Increase condition find outside three anyone.',
#   'duration': 15,
#   'tags': ['Home', '']},
#  {'title': 'Laundry',
#   'description': 'Reveal food this.',
#   'duration': 36,
#   'tags': ['Home', '']},
#  {'title': 'Clean Room',
#   'description': 'Four true culture station.',
#   'duration': 37,
#   'tags': ['Home', '']},
#  {'title': 'Clean Room',
#   'description': 'Leg while baby arrive they.',
#   'duration': 37,
#   'tags': ['Home', '']},
#  {'title': 'Clean Room',
#   'description': 'Style condition fast memory mean development.',
#   'duration': 37,
#   'tags': ['Home', '']},
#  {'title': 'Change Bed Sheets',
#   'description': 'Response debate truth agreement control leave without.',
#   'duration': 40,
#   'tags': ['Home', '']},
#  {'title': 'Clean Room',
#   'description': 'Rate six often model close daughter TV director.',
#   'duration': 24,
#   'tags': ['Home', '']},
#  {'title': 'Clean Room',
#   'description': 'Nation debate green my.',
#   'duration': 23,
#   'tags': ['Home', '']},
#  {'title': 'Change Bed Sheets',
#   'description': 'Town tax smile.',
#   'duration': 29,
#   'tags': ['Home', '']},
#  {'title': 'Change Bed Sheets',
#   'description': 'Top sing executive marriage.',
#   'duration': 30,
#   'tags': ['Home', '']},
#  {'title': 'Clean Room',
#   'description': 'Management able old democratic.',
#   'duration': 32,
#   'tags': ['Home', '']},
#  {'title': 'Clean Room',
#   'description': 'Drive even stock.',
#   'duration': 37,
#   'tags': ['Home', '']},
#  {'title': 'Clean Room',
#   'description': 'Financial administration remain before score value garden.',
#   'duration': 27,
#   'tags': ['Home', '']},
#  {'title': 'Change Bed Sheets',
#   'description': 'Across site sister.',
#   'duration': 39,
#   'tags': ['Home', '']},
#  {'title': 'Laundry',
#   'description': 'Yet where young down day value some new.',
#   'duration': 18,
#   'tags': ['Home', '']},
#  {'title': 'Clean Room',
#   'description': 'Two onto top air answer side week.',
#   'duration': 20,
#   'tags': ['Home', '']},
#  {'title': 'Laundry',
#   'description': 'Example discuss three discussion military.',
#   'duration': 16,
#   'tags': ['Home', '']},
#  {'title': 'Laundry',
#   'description': 'Main year plant less simply.',
#   'duration': 30,
#   'tags': ['Home', '']},
#  {'title': 'Laundry',
#   'description': 'High staff account.',
#   'duration': 28,
#   'tags': ['Home', '']},
#  {'title': 'Laundry',
#   'description': 'Really at it tonight quickly center perhaps.',
#   'duration': 35,
#   'tags': ['Home', '']},
#  {'title': 'Change Bed Sheets',
#   'description': 'Yes compare east mention question.',
#   'duration': 31,
#   'tags': ['Home', '']},
#  {'title': 'Clean Room',
#   'description': 'In hour exist peace.',
#   'duration': 30,
#   'tags': ['Home', '']},
#  {'title': 'Laundry',
#   'description': 'Give receive job old.',
#   'duration': 16,
#   'tags': ['Home', '']},
#  {'title': 'Laundry',
#   'description': 'Material also guy say.',
#   'duration': 39,
#   'tags': ['Home', '']}]
